# %% [markdown]
# <a href="https://colab.research.google.com/github/EMockevicius/deep-learning/blob/main/basic_models_finished.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep learning model used for function aproximation
# ## Basic models
#
# Let's try to compile basic model, try to visualize the model structure, generate some data, do basic training, try accessing layers' weights, save and load models and weights, try predicting values (perform inference).

# %% [markdown]
# If you  are using Tensorflow 2.x, then the model creation with Keras start by importing the necessary libraries. If you have a version with nVidia GPU support, then you can set environment variable to execute model on CPU or GPU:

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # '-1' is CPU, '0' - 1st GPU, '1' - 2nd GPU...

# %%
import tensorflow.keras as keras #we will be using keras module only

# %% [markdown]
# ## Defining model
#
# We need to define our model by giving input shape, layers and output.
#
# Lets make the first model with just a single input, use 2 neurons dense layer with ReLU activation, then dense layer with 1 neuron and Sigmoid activation:

# %%
def define_small_model():
    # input will be a single floating point number
    model_input = keras.layers.Input(shape=(1,), dtype="float32", name="input")
    
    # first layer will be made of 2 neurons
    x = keras.layers.Dense(2, name="dense_layer_1")(model_input)
    
    # let's use ReLU activation after dense layer
    x = keras.activations.relu(x)
    
    # layer made of 1 neuron
    x = keras.layers.Dense(1, name="dense_layer_2")(x)
    
    # this time we use Sigmoid activation
    model_output = keras.activations.sigmoid(x)
    
    # now model inputs and outputs should be provided in a lists
    model = keras.Model(inputs=[model_input], outputs=[model_output])
    
    return model

# %% [markdown]
# ## Model visualization
#
# By calling the function we can get our model:

# %%
our_small_model = define_small_model()

# %% [markdown]
# Lets do some visualizations to see if the model is of the right structure and shape.
# Basic check is by calling model summary:

# %%
our_small_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 1)]               0
#
#  dense_layer_1 (Dense)       (None, 2)                 4
#
#  tf.nn.relu (TFOpLambda)     (None, 2)                 0
#
#  dense_layer_2 (Dense)       (None, 1)                 3
#
#  tf.math.sigmoid (TFOpLambda  (None, 1)                0
#  )
#
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# By checking **Param #** column we can see how many parameters (usually weights) each layer has.

# %%
keras.utils.plot_model(our_small_model, to_file="our_small_model.jpg",
                       show_shapes=True,
                       show_layer_names=True,
                       rankdir="TB",
                       dpi=96)

# %% [markdown]
# Question mark points to batch size, as in all modern frameworks data is usually supplied in batches. Even a single sample is supplied as a batch of size 1. So a single number will be supplied as a matrix of size (1, 1).
#
# Lets try another tiny model:

# %%
def define_tiny_model():
    # single input will be two floating point numbers supplied at the same time (vector of two number)
    model_input = keras.layers.Input(shape=(2,), dtype="float32", name="input")
    
    # single layer with 3 neurons and ReLU activation
    # activation could be defined as separate layer or as part of the current layer (if supported)
    model_output = keras.layers.Dense(3, use_bias=True, activation="relu", name="dense_1")(model_input)
    
    # now model inputs and outputs should be provided in a lists
    model = keras.Model(inputs=[model_input], outputs=[model_output])
    
    return model

# %%
our_tiny_model = define_tiny_model()

# %%
our_tiny_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3)                 9
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We have got total 9 trainable parameters. This is because we have a Dense layer (fully connected) with 3 neurons and input which is made of 2 numbers. So we have 2 x 3 = 6 weights and also we need to add biases (for every neuron in dense layer), 2 x 3 + 3 = 9 parameters.

# %%
keras.utils.plot_model(our_tiny_model, to_file="our_tiny_model.jpg",
                       show_shapes=True,
                       show_layer_names=True,
                       rankdir="TB",
                       dpi=96)

# %% [markdown]
# ## Model training
#
# To train a model, we need input and output data. So lets import libraries to work with matrices and plotting tools.

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Our problem will be a $f(x) = sin(x)$ function defined in a range [-10;10].

# %%
#input_data = np.linspace(-10, 10, num=1000)
##input_data = np.linspace(-1000, 1000, num=100000)
#output_data = np.sin(input_data)

# %%
#plt.figure()
#plt.grid()
#plt.title("Custom function")
#plt.xlabel("x")
#plt.ylabel("y")
##plt.plot(input_data[0:100], output_data[0:100]);
#plt.plot(input_data, output_data);

# %% [markdown]
# #naudosime $f(x) = sin(2x) + sin(x)$ pagal 1 ld aprašymą
# koreguojame pagal pvz aukščiau

# %%
input_data = np.linspace(-10, 10, num=1000)
output_data = np.sin(2*input_data) + np.sin(input_data)

# %%
plt.figure()
plt.grid()
plt.title("f(x) = Sin(2x) + sin(x)")
plt.ylabel('y (output_data)')
plt.xlabel('x (input_data)')     
#input_data = list(input_data)
plt.plot(input_data, output_data)
#plt.show()

# %% [markdown]
# Our problem is a regression as we are trying to predict a quantity.

# %% [markdown]
# We will define some experimental model with 5 layers, 1 input and 1 output. Take a note, that there is no activation function (linear activation) in the last layer as predicted quantity could be positive and negative.

# %%
def experimental_model():
    # single input will be two floating point numbers supplied at the same time (vector of two number)
    model_input = keras.layers.Input(shape=(1,), dtype="float32", name="input")
    
    # activation could be defined as separate layer or as part of the current layer (if supported)
    x = keras.layers.Dense(40, use_bias=True, activation="relu", name="dense_1")(model_input)
    x = keras.layers.Dense(30, use_bias=True, activation="relu", name="dense_2")(x)
    x = keras.layers.Dense(20, use_bias=True, activation="relu", name="dense_3")(x)
    x = keras.layers.Dense(10, use_bias=True, activation="relu", name="dense_4")(x)
    # we can use loops to add more layers
    #for i in range(5, 10):
    #    x = keras.layers.Dense(10, use_bias=True, activation="relu", name="dense_"+str(i))(x)
        
    model_output = keras.layers.Dense(1, use_bias=True, name="dense_output")(x)
    # now model inputs and outputs should be provided in a lists
    model = keras.Model(inputs=[model_input], outputs=[model_output])
    
    return model

# %% [markdown]
# After model is compiled its graph is static and it is ready to be trained. To compile model we need to define optimization algorithm (the one which will adjust weights of the model) [https://keras.io/api/optimizers/](https://keras.io/api/optimizers/), loss function [https://keras.io/api/losses/](https://keras.io/api/losses/) aka objective function (one which tell optimizer how to calculate error, and optimizer will try to minimize that error) and metrics (error(s) for visualization purposes) [https://keras.io/api/metrics/](https://keras.io/api/metrics/).

# %% [markdown]
# For optimizer it is recommended to start with **ADAM** (stochastic gradient descent with Adaptive Momentum) [https://keras.io/api/optimizers/adam/](https://keras.io/api/optimizers/adam/), then try **SGD** (Scaled Gradient Descent) [https://keras.io/api/optimizers/sgd/](https://keras.io/api/optimizers/sgd/) if **ADAM** is not working. Another good one to try is **RMSprop** [https://keras.io/api/optimizers/rmsprop/](https://keras.io/api/optimizers/rmsprop/).
#
# During training [https://keras.io/api/models/model_training_apis/#fit-method](https://keras.io/api/models/model_training_apis/#fit-method) it is necessary to check if model is not overfitting the data. So we divide the data into train set and validation set by setting ```validation_split``` parameter, to determine percentage of data used for validation.

# %% [markdown]
# It is recommended to shuffle the data prior splitting into train and validation.

# %%
def shuffled_copies(a, b): #both arrays should have the same length
    p = np.random.permutation(len(a)) #get shuffled indexes
    return a[p], b[p]

shuffled_input_data, shuffled_output_data = shuffled_copies(input_data, output_data)

# %% [markdown]
# Let's create our model and visualize its structure:

# %%
model = experimental_model()

# %%
model.summary()
keras.utils.plot_model(model, to_file="experimental_model.jpg",
                       show_shapes=True,
                       show_layer_names=True,
                       rankdir="TB",
                       dpi=96)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 1)]               0
#
#  dense_1 (Dense)             (None, 40)                80
#
#  dense_2 (Dense)             (None, 30)                1230
#
#  dense_3 (Dense)             (None, 20)                620
#
#  dense_4 (Dense)             (None, 10)                210
#
#  dense_output (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 2,151
# Trainable params: 2,151
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we can define optimizer, loss function, metric, batch size, number of epochs, compile model (create static graph) and train it.

# %%
opt = keras.optimizers.Adam()
#opt = keras.optimizers.RMSprop()
loss = keras.losses.MeanSquaredError()
metric_mae = keras.metrics.MeanAbsoluteError()

model.compile(optimizer=opt,
              loss=loss,
              metrics=[metric_mae],
              run_eagerly=False,)

# %%
batch_size = 2
epochs = 150
#epochs = 5

#model.fit(input_data, output_data, batch_size=batch_size, epochs=epochs, validation_split=0.1)
model.fit(shuffled_input_data,
          shuffled_output_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.1);
# Out:
# Epoch 1/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.9526 - mean_absolute_error: 0.7693 - val_loss: 0.8552 - val_mean_absolute_error: 0.7409
# Epoch 2/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8555 - mean_absolute_error: 0.7277 - val_loss: 0.7286 - val_mean_absolute_error: 0.6713
# Epoch 3/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.7210 - mean_absolute_error: 0.6441 - val_loss: 0.6212 - val_mean_absolute_error: 0.5757
# Epoch 4/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6414 - mean_absolute_error: 0.5627 - val_loss: 0.6024 - val_mean_absolute_error: 0.5310
# Epoch 5/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6270 - mean_absolute_error: 0.5396 - val_loss: 0.5954 - val_mean_absolute_error: 0.5264
# Epoch 6/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6243 - mean_absolute_error: 0.5306 - val_loss: 0.5921 - val_mean_absolute_error: 0.5175
# Epoch 7/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6252 - mean_absolute_error: 0.5349 - val_loss: 0.5908 - val_mean_absolute_error: 0.5291
# Epoch 8/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6260 - mean_absolute_error: 0.5438 - val_loss: 0.5972 - val_mean_absolute_error: 0.5372
# Epoch 9/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6189 - mean_absolute_error: 0.5365 - val_loss: 0.6102 - val_mean_absolute_error: 0.5415
# Epoch 10/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6250 - mean_absolute_error: 0.5496 - val_loss: 0.5957 - val_mean_absolute_error: 0.5366
# Epoch 11/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6183 - mean_absolute_error: 0.5371 - val_loss: 0.5874 - val_mean_absolute_error: 0.5307
# Epoch 12/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6170 - mean_absolute_error: 0.5391 - val_loss: 0.5802 - val_mean_absolute_error: 0.5332
# Epoch 13/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6029 - mean_absolute_error: 0.5307 - val_loss: 0.5616 - val_mean_absolute_error: 0.5153
# Epoch 14/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.6006 - mean_absolute_error: 0.5349 - val_loss: 0.5422 - val_mean_absolute_error: 0.5058
# Epoch 15/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5829 - mean_absolute_error: 0.5289 - val_loss: 0.5316 - val_mean_absolute_error: 0.5225
# Epoch 16/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5622 - mean_absolute_error: 0.5165 - val_loss: 0.5013 - val_mean_absolute_error: 0.5037
# Epoch 17/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5441 - mean_absolute_error: 0.5077 - val_loss: 0.4951 - val_mean_absolute_error: 0.4836
# Epoch 18/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5204 - mean_absolute_error: 0.4949 - val_loss: 0.4460 - val_mean_absolute_error: 0.4868
# Epoch 19/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5166 - mean_absolute_error: 0.4931 - val_loss: 0.5408 - val_mean_absolute_error: 0.5023
# Epoch 20/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.5050 - mean_absolute_error: 0.4738 - val_loss: 0.3997 - val_mean_absolute_error: 0.4107
# Epoch 21/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4823 - mean_absolute_error: 0.4545 - val_loss: 0.4133 - val_mean_absolute_error: 0.4313
# Epoch 22/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4735 - mean_absolute_error: 0.4576 - val_loss: 0.3852 - val_mean_absolute_error: 0.4049
# Epoch 23/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4674 - mean_absolute_error: 0.4487 - val_loss: 0.3725 - val_mean_absolute_error: 0.3877
# Epoch 24/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4623 - mean_absolute_error: 0.4404 - val_loss: 0.3855 - val_mean_absolute_error: 0.4137
# Epoch 25/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4572 - mean_absolute_error: 0.4394 - val_loss: 0.3715 - val_mean_absolute_error: 0.3813
# Epoch 26/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4556 - mean_absolute_error: 0.4379 - val_loss: 0.3785 - val_mean_absolute_error: 0.4186
# Epoch 27/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4625 - mean_absolute_error: 0.4459 - val_loss: 0.3579 - val_mean_absolute_error: 0.3543
# Epoch 28/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4407 - mean_absolute_error: 0.4226 - val_loss: 0.3563 - val_mean_absolute_error: 0.3581
# Epoch 29/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4524 - mean_absolute_error: 0.4376 - val_loss: 0.3576 - val_mean_absolute_error: 0.3799
# Epoch 30/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4275 - mean_absolute_error: 0.4115 - val_loss: 0.3357 - val_mean_absolute_error: 0.3529
# Epoch 31/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4228 - mean_absolute_error: 0.4177 - val_loss: 0.3313 - val_mean_absolute_error: 0.3678
# Epoch 32/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.4195 - mean_absolute_error: 0.4260 - val_loss: 0.3327 - val_mean_absolute_error: 0.3985
# Epoch 33/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3715 - mean_absolute_error: 0.3729 - val_loss: 0.2896 - val_mean_absolute_error: 0.3158
# Epoch 34/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3560 - mean_absolute_error: 0.3570 - val_loss: 0.2909 - val_mean_absolute_error: 0.3233
# Epoch 35/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3939 - mean_absolute_error: 0.3917 - val_loss: 0.2867 - val_mean_absolute_error: 0.3325
# Epoch 36/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3517 - mean_absolute_error: 0.3511 - val_loss: 0.2710 - val_mean_absolute_error: 0.2745
# Epoch 37/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3632 - mean_absolute_error: 0.3632 - val_loss: 0.2742 - val_mean_absolute_error: 0.2870
# Epoch 38/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3432 - mean_absolute_error: 0.3358 - val_loss: 0.2789 - val_mean_absolute_error: 0.3105
# Epoch 39/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3452 - mean_absolute_error: 0.3427 - val_loss: 0.2702 - val_mean_absolute_error: 0.2801
# Epoch 40/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3474 - mean_absolute_error: 0.3472 - val_loss: 0.2931 - val_mean_absolute_error: 0.3449
# Epoch 41/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3487 - mean_absolute_error: 0.3459 - val_loss: 0.2785 - val_mean_absolute_error: 0.3147
# Epoch 42/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3403 - mean_absolute_error: 0.3356 - val_loss: 0.2708 - val_mean_absolute_error: 0.2906
# Epoch 43/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3392 - mean_absolute_error: 0.3278 - val_loss: 0.2703 - val_mean_absolute_error: 0.2920
# Epoch 44/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3564 - mean_absolute_error: 0.3517 - val_loss: 0.3071 - val_mean_absolute_error: 0.3520
# Epoch 45/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3410 - mean_absolute_error: 0.3316 - val_loss: 0.2871 - val_mean_absolute_error: 0.3397
# Epoch 46/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3488 - mean_absolute_error: 0.3479 - val_loss: 0.2696 - val_mean_absolute_error: 0.2876
# Epoch 47/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3357 - mean_absolute_error: 0.3188 - val_loss: 0.2679 - val_mean_absolute_error: 0.2818
# Epoch 48/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3400 - mean_absolute_error: 0.3284 - val_loss: 0.2751 - val_mean_absolute_error: 0.3103
# Epoch 49/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3466 - mean_absolute_error: 0.3476 - val_loss: 0.2828 - val_mean_absolute_error: 0.3239
# Epoch 50/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3435 - mean_absolute_error: 0.3349 - val_loss: 0.2665 - val_mean_absolute_error: 0.2720
# Epoch 51/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3419 - mean_absolute_error: 0.3377 - val_loss: 0.2800 - val_mean_absolute_error: 0.3039
# Epoch 52/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3496 - mean_absolute_error: 0.3534 - val_loss: 0.2812 - val_mean_absolute_error: 0.3097
# Epoch 53/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3451 - mean_absolute_error: 0.3370 - val_loss: 0.2908 - val_mean_absolute_error: 0.3328
# Epoch 54/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3487 - mean_absolute_error: 0.3408 - val_loss: 0.2664 - val_mean_absolute_error: 0.2738
# Epoch 55/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3362 - mean_absolute_error: 0.3232 - val_loss: 0.2659 - val_mean_absolute_error: 0.2742
# Epoch 56/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3432 - mean_absolute_error: 0.3346 - val_loss: 0.2784 - val_mean_absolute_error: 0.3091
# Epoch 57/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3408 - mean_absolute_error: 0.3335 - val_loss: 0.2680 - val_mean_absolute_error: 0.2787
# Epoch 58/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3396 - mean_absolute_error: 0.3328 - val_loss: 0.2666 - val_mean_absolute_error: 0.2750
# Epoch 59/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3509 - mean_absolute_error: 0.3465 - val_loss: 0.2967 - val_mean_absolute_error: 0.3230
# Epoch 60/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3483 - mean_absolute_error: 0.3438 - val_loss: 0.2701 - val_mean_absolute_error: 0.2838
# Epoch 61/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3475 - mean_absolute_error: 0.3400 - val_loss: 0.2733 - val_mean_absolute_error: 0.2931
# Epoch 62/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3391 - mean_absolute_error: 0.3330 - val_loss: 0.2733 - val_mean_absolute_error: 0.3016
# Epoch 63/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3432 - mean_absolute_error: 0.3399 - val_loss: 0.2683 - val_mean_absolute_error: 0.2873
# Epoch 64/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3383 - mean_absolute_error: 0.3290 - val_loss: 0.2694 - val_mean_absolute_error: 0.2818
# Epoch 65/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3501 - mean_absolute_error: 0.3377 - val_loss: 0.2705 - val_mean_absolute_error: 0.2829
# Epoch 66/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3340 - mean_absolute_error: 0.3174 - val_loss: 0.2694 - val_mean_absolute_error: 0.2837
# Epoch 67/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3368 - mean_absolute_error: 0.3223 - val_loss: 0.3306 - val_mean_absolute_error: 0.3709
# Epoch 68/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3444 - mean_absolute_error: 0.3333 - val_loss: 0.2652 - val_mean_absolute_error: 0.2670
# Epoch 69/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3411 - mean_absolute_error: 0.3351 - val_loss: 0.2749 - val_mean_absolute_error: 0.3067
# Epoch 70/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3405 - mean_absolute_error: 0.3270 - val_loss: 0.2667 - val_mean_absolute_error: 0.2824
# Epoch 71/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3308 - mean_absolute_error: 0.3076 - val_loss: 0.2660 - val_mean_absolute_error: 0.2710
# Epoch 72/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3778 - mean_absolute_error: 0.3652 - val_loss: 0.2659 - val_mean_absolute_error: 0.2742
# Epoch 73/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3325 - mean_absolute_error: 0.3122 - val_loss: 0.2637 - val_mean_absolute_error: 0.2591
# Epoch 74/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3331 - mean_absolute_error: 0.3181 - val_loss: 0.2731 - val_mean_absolute_error: 0.3025
# Epoch 75/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3354 - mean_absolute_error: 0.3196 - val_loss: 0.2626 - val_mean_absolute_error: 0.2604
# Epoch 76/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3348 - mean_absolute_error: 0.3243 - val_loss: 0.2652 - val_mean_absolute_error: 0.2780
# Epoch 77/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3497 - mean_absolute_error: 0.3440 - val_loss: 0.2675 - val_mean_absolute_error: 0.2843
# Epoch 78/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3310 - mean_absolute_error: 0.3103 - val_loss: 0.2641 - val_mean_absolute_error: 0.2660
# Epoch 79/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3287 - mean_absolute_error: 0.3046 - val_loss: 0.2630 - val_mean_absolute_error: 0.2716
# Epoch 80/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3370 - mean_absolute_error: 0.3212 - val_loss: 0.2807 - val_mean_absolute_error: 0.3127
# Epoch 81/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3552 - mean_absolute_error: 0.3487 - val_loss: 0.2680 - val_mean_absolute_error: 0.2907
# Epoch 82/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3325 - mean_absolute_error: 0.3120 - val_loss: 0.2741 - val_mean_absolute_error: 0.3093
# Epoch 83/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3278 - mean_absolute_error: 0.2994 - val_loss: 0.2619 - val_mean_absolute_error: 0.2557
# Epoch 84/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3333 - mean_absolute_error: 0.3166 - val_loss: 0.2684 - val_mean_absolute_error: 0.2849
# Epoch 85/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3291 - mean_absolute_error: 0.3057 - val_loss: 0.2635 - val_mean_absolute_error: 0.2704
# Epoch 86/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3294 - mean_absolute_error: 0.3065 - val_loss: 0.2640 - val_mean_absolute_error: 0.2691
# Epoch 87/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3371 - mean_absolute_error: 0.3164 - val_loss: 0.2655 - val_mean_absolute_error: 0.2723
# Epoch 88/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3322 - mean_absolute_error: 0.3076 - val_loss: 0.2633 - val_mean_absolute_error: 0.2678
# Epoch 89/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3292 - mean_absolute_error: 0.3054 - val_loss: 0.2648 - val_mean_absolute_error: 0.2755
# Epoch 90/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3306 - mean_absolute_error: 0.3095 - val_loss: 0.2614 - val_mean_absolute_error: 0.2566
# Epoch 91/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3289 - mean_absolute_error: 0.3002 - val_loss: 0.2695 - val_mean_absolute_error: 0.2827
# Epoch 92/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3301 - mean_absolute_error: 0.3081 - val_loss: 0.2616 - val_mean_absolute_error: 0.2578
# Epoch 93/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3369 - mean_absolute_error: 0.3221 - val_loss: 0.2668 - val_mean_absolute_error: 0.2833
# Epoch 94/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3285 - mean_absolute_error: 0.3019 - val_loss: 0.2673 - val_mean_absolute_error: 0.2719
# Epoch 95/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3292 - mean_absolute_error: 0.3042 - val_loss: 0.2610 - val_mean_absolute_error: 0.2483
# Epoch 96/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3307 - mean_absolute_error: 0.3079 - val_loss: 0.2640 - val_mean_absolute_error: 0.2677
# Epoch 97/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3316 - mean_absolute_error: 0.3046 - val_loss: 0.2853 - val_mean_absolute_error: 0.3136
# Epoch 98/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3293 - mean_absolute_error: 0.3045 - val_loss: 0.2632 - val_mean_absolute_error: 0.2640
# Epoch 99/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3274 - mean_absolute_error: 0.3000 - val_loss: 0.2760 - val_mean_absolute_error: 0.2937
# Epoch 100/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3310 - mean_absolute_error: 0.3098 - val_loss: 0.2692 - val_mean_absolute_error: 0.2883
# Epoch 101/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3326 - mean_absolute_error: 0.3140 - val_loss: 0.2616 - val_mean_absolute_error: 0.2567
# Epoch 102/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3269 - mean_absolute_error: 0.2987 - val_loss: 0.2620 - val_mean_absolute_error: 0.2594
# Epoch 103/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3304 - mean_absolute_error: 0.3087 - val_loss: 0.2664 - val_mean_absolute_error: 0.2780
# Epoch 104/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3267 - mean_absolute_error: 0.2966 - val_loss: 0.2639 - val_mean_absolute_error: 0.2727
# Epoch 105/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3268 - mean_absolute_error: 0.2943 - val_loss: 0.2645 - val_mean_absolute_error: 0.2632
# Epoch 106/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3276 - mean_absolute_error: 0.3027 - val_loss: 0.2613 - val_mean_absolute_error: 0.2556
# Epoch 107/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3566 - mean_absolute_error: 0.3437 - val_loss: 0.2609 - val_mean_absolute_error: 0.2517
# Epoch 108/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3246 - mean_absolute_error: 0.2885 - val_loss: 0.2605 - val_mean_absolute_error: 0.2497
# Epoch 109/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3247 - mean_absolute_error: 0.2869 - val_loss: 0.2614 - val_mean_absolute_error: 0.2539
# Epoch 110/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3352 - mean_absolute_error: 0.3113 - val_loss: 0.2984 - val_mean_absolute_error: 0.3449
# Epoch 111/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3280 - mean_absolute_error: 0.3022 - val_loss: 0.2649 - val_mean_absolute_error: 0.2685
# Epoch 112/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3260 - mean_absolute_error: 0.2946 - val_loss: 0.2703 - val_mean_absolute_error: 0.2715
# Epoch 113/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3313 - mean_absolute_error: 0.3088 - val_loss: 0.2623 - val_mean_absolute_error: 0.2619
# Epoch 114/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3293 - mean_absolute_error: 0.3031 - val_loss: 0.2679 - val_mean_absolute_error: 0.2700
# Epoch 115/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3313 - mean_absolute_error: 0.2980 - val_loss: 0.2826 - val_mean_absolute_error: 0.3090
# Epoch 116/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3360 - mean_absolute_error: 0.3245 - val_loss: 0.2620 - val_mean_absolute_error: 0.2583
# Epoch 117/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3253 - mean_absolute_error: 0.2912 - val_loss: 0.2656 - val_mean_absolute_error: 0.2778
# Epoch 118/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3259 - mean_absolute_error: 0.2937 - val_loss: 0.2603 - val_mean_absolute_error: 0.2459
# Epoch 119/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3352 - mean_absolute_error: 0.3233 - val_loss: 0.2623 - val_mean_absolute_error: 0.2639
# Epoch 120/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3246 - mean_absolute_error: 0.2850 - val_loss: 0.2603 - val_mean_absolute_error: 0.2438
# Epoch 121/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3268 - mean_absolute_error: 0.2947 - val_loss: 0.2673 - val_mean_absolute_error: 0.2812
# Epoch 122/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3335 - mean_absolute_error: 0.3047 - val_loss: 0.4151 - val_mean_absolute_error: 0.4142
# Epoch 123/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3387 - mean_absolute_error: 0.3105 - val_loss: 0.2615 - val_mean_absolute_error: 0.2537
# Epoch 124/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3272 - mean_absolute_error: 0.3003 - val_loss: 0.2634 - val_mean_absolute_error: 0.2698
# Epoch 125/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3276 - mean_absolute_error: 0.2980 - val_loss: 0.2900 - val_mean_absolute_error: 0.3173
# Epoch 126/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3301 - mean_absolute_error: 0.3026 - val_loss: 0.2624 - val_mean_absolute_error: 0.2612
# Epoch 127/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3267 - mean_absolute_error: 0.2942 - val_loss: 0.2680 - val_mean_absolute_error: 0.2815
# Epoch 128/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3283 - mean_absolute_error: 0.3033 - val_loss: 0.2613 - val_mean_absolute_error: 0.2562
# Epoch 129/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3276 - mean_absolute_error: 0.2950 - val_loss: 0.2758 - val_mean_absolute_error: 0.3159
# Epoch 130/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3352 - mean_absolute_error: 0.3167 - val_loss: 0.2627 - val_mean_absolute_error: 0.2608
# Epoch 131/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3249 - mean_absolute_error: 0.2878 - val_loss: 0.2609 - val_mean_absolute_error: 0.2511
# Epoch 132/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3327 - mean_absolute_error: 0.3056 - val_loss: 0.3420 - val_mean_absolute_error: 0.3740
# Epoch 133/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3337 - mean_absolute_error: 0.3095 - val_loss: 0.2614 - val_mean_absolute_error: 0.2544
# Epoch 134/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3242 - mean_absolute_error: 0.2852 - val_loss: 0.2612 - val_mean_absolute_error: 0.2524
# Epoch 135/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3380 - mean_absolute_error: 0.3156 - val_loss: 0.2652 - val_mean_absolute_error: 0.2774
# Epoch 136/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3252 - mean_absolute_error: 0.2908 - val_loss: 0.2602 - val_mean_absolute_error: 0.2458
# Epoch 137/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3284 - mean_absolute_error: 0.2999 - val_loss: 0.2614 - val_mean_absolute_error: 0.2542
# Epoch 138/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3276 - mean_absolute_error: 0.2938 - val_loss: 0.2706 - val_mean_absolute_error: 0.2779
# Epoch 139/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3250 - mean_absolute_error: 0.2883 - val_loss: 0.2640 - val_mean_absolute_error: 0.2707
# Epoch 140/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3291 - mean_absolute_error: 0.3015 - val_loss: 0.2601 - val_mean_absolute_error: 0.2444
# Epoch 141/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3249 - mean_absolute_error: 0.2870 - val_loss: 0.2608 - val_mean_absolute_error: 0.2458
# Epoch 142/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3284 - mean_absolute_error: 0.2974 - val_loss: 0.2602 - val_mean_absolute_error: 0.2440
# Epoch 143/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3272 - mean_absolute_error: 0.2944 - val_loss: 0.2612 - val_mean_absolute_error: 0.2543
# Epoch 144/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3247 - mean_absolute_error: 0.2855 - val_loss: 0.2663 - val_mean_absolute_error: 0.2797
# Epoch 145/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3298 - mean_absolute_error: 0.3056 - val_loss: 0.2628 - val_mean_absolute_error: 0.2653
# Epoch 146/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3328 - mean_absolute_error: 0.3083 - val_loss: 0.2608 - val_mean_absolute_error: 0.2481
# Epoch 147/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3233 - mean_absolute_error: 0.2782 - val_loss: 0.2613 - val_mean_absolute_error: 0.2547
# Epoch 148/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3263 - mean_absolute_error: 0.2932 - val_loss: 0.2610 - val_mean_absolute_error: 0.2518
# Epoch 149/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3284 - mean_absolute_error: 0.3005 - val_loss: 0.2617 - val_mean_absolute_error: 0.2570
# Epoch 150/150
# 450/450 [==============================] - 1s 2ms/step - loss: 0.3322 - mean_absolute_error: 0.3033 - val_loss: 0.2620 - val_mean_absolute_error: 0.2608

# %%
predicted_data = model.predict(input_data)

# %%
plt.figure()
plt.grid()
plt.title("Prediction vs original")
plt.xlabel("x")
plt.ylabel("y")
#plt.plot(input_data[0:1000], output_data[0:1000], input_data[0:1000], predicted_data[0:1000]);
plt.plot(input_data, output_data, input_data, predicted_data);
print(predicted_data.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ## Saving model and weights

# %% [markdown]
# It is recommended to save model and model weights every epoch, so later it is possible to look through models and get the most suitable one.
#
# When saving model, model structure, weights and optimizer state are saved. When saving weights only, you don't have information on model structure or state of optimizer, so it is recommended to have model structure source file.
#
# Model saving is done via `keras.models.save_model` function. If you don't know the function options, type function name with a question mark `keras.models.save_model?` and execute cell.

# %%
keras.models.save_model?

# %%
model.save_weights?

# %%
# to get help use model.save?
#model.save("sine_function_model.h5") #old approach
keras.models.save_model(model, "sine_function_model.h5")
model.save_weights("sine_function_model_weights.h5")

# %% [markdown]
# Model could be deleted from memory and then loaded again easy:

# %%
del model #delete model
model = keras.models.load_model("sine_function_model.h5")

# %% [markdown]
# If we create custom layers or custom activations, then such saved model may not load as those custom modifications are not present in keras library. In such a case we need to recreate model structure from the function and then load weights.

# %%
del model #delete model
model = experimental_model()
model.load_weights("sine_function_model_weights.h5")

# %% [markdown]
# After loading we may again perform an inference by supplying `input_data` and noting the predictions.

# %%
predicted_data = model.predict(input_data)

# %%
plt.figure()
plt.grid()
plt.title("Prediction vs original")
plt.xlabel("x")
plt.ylabel("y")
#plt.plot(input_data[0:100], output_data[0:100]);
#plt.plot(input_data, predicted_data);
plt.plot(input_data, output_data, input_data, predicted_data);
print(predicted_data.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ## Model testing

# %% [markdown]
# We can try to extend the range and check how well the model performs outside of the train range (how well model extrapolates)

# %%
input_data_long = np.linspace(-20, 20, num=1000)
#output_data_long = np.sin(input_data_long)
output_data_long = np.sin(2*input_data_long) + np.sin(input_data_long)

# %%
predicted_data_long = model.predict(input_data_long)

# %%
plt.figure()
plt.grid()
plt.title("Prediction vs original (long version)")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(input_data_long, output_data_long, input_data_long, predicted_data_long);
print(predicted_data_long.shape)
# Out:
# (1000, 1)

# %% [markdown]
# Outside of training data model behaves poorly. Because of these reasons:
# * We are trying to model periodic function with non-periodic activations. For such task we need a lot of memory (wide feed forward model) to memorize all values from all usable range.
# * Or we need a periodic activation function for our feed forward model (we will try that later).
# * Or use model which can remember previous states (recurrent model based on LSTM or GRU).

# %% [markdown]
# ## Manipulations with weights

# %% [markdown]
# Reading weights of trained model may help to understand why model is performing poorly. Also weights may be adjusted or transfered to other model.

# %% [markdown]
# When building model it is recommended to provide names to model layers, so later you can access layers by name instead of by index [https://keras.io/api/layers/base_layer/#get_weights-method](https://keras.io/api/layers/base_layer/#get_weights-method):

# %%
one_layer = model.get_layer(name="dense_1")
one_layer_weights = one_layer.get_weights()

# %%
print(one_layer_weights[0].shape)
print(one_layer_weights[1].shape)
print(one_layer_weights)
# Out:
# (1, 40)
# (40,)
# [array([[ 6.5499440e-02,  3.0745784e-02, -2.5245082e-01,  3.9263591e-03,
#         -1.5696935e-01,  5.2001290e-02, -2.4026755e-02,  5.2406702e-02,
#          3.7566465e-01,  4.3604377e-01,  9.0677559e-02, -1.2552904e-02,
#          3.6227104e-01,  5.8624709e-01,  6.5383799e-02,  2.4597977e-01,
#         -3.5579291e-01,  8.9360578e-03,  7.8113079e-02,  9.4349153e-02,
#          4.3511194e-01,  5.0326507e-04, -2.7879658e-01, -2.5895801e-01,
#         -2.4279262e-01,  1.1158445e-01,  3.1619403e-01,  3.1753534e-01,
#         -1.3183555e-01,  4.0391237e-01,  4.8740411e-01,  1.6134145e-03,
#          3.6207208e-01,  4.1499713e-01,  3.5819587e-01,  7.8359872e-02,
#          8.3928429e-02,  5.5315322e-04,  4.8179794e-03, -2.3667416e-02]],
#       dtype=float32), array([ 0.5763189 ,  0.10857808, -0.7472926 , -0.02216879, -0.6916393 ,
#         0.30670565, -0.24206689,  0.13332878,  0.26381198,  0.19511506,
#         0.29662633, -0.13197671,  0.29786748, -0.0083971 ,  0.6694985 ,
#         0.21015643, -0.8283723 , -0.03457905,  0.7559842 ,  0.19104497,
#         0.09049685, -0.04621683, -0.32076493, -0.3321562 , -0.26362398,
#         0.2908418 ,  0.1951135 ,  0.24258041, -0.72133464, -0.4394371 ,
#        -0.43302915, -0.02720774, -0.3920092 , -0.47290337,  0.30674335,
#         0.77210724,  0.841289  , -0.00897525, -0.01563014, -0.24336718],
#       dtype=float32)]

# %% [markdown]
# Same weights are available when accessing layer by index:

# %%
one_layer = model.get_layer(index=1)
one_layer_weights = one_layer.get_weights()

# %%
print(one_layer_weights[0].shape)
print(one_layer_weights[1].shape)
print(one_layer_weights)
# Out:
# (1, 40)
# (40,)
# [array([[ 6.5499440e-02,  3.0745784e-02, -2.5245082e-01,  3.9263591e-03,
#         -1.5696935e-01,  5.2001290e-02, -2.4026755e-02,  5.2406702e-02,
#          3.7566465e-01,  4.3604377e-01,  9.0677559e-02, -1.2552904e-02,
#          3.6227104e-01,  5.8624709e-01,  6.5383799e-02,  2.4597977e-01,
#         -3.5579291e-01,  8.9360578e-03,  7.8113079e-02,  9.4349153e-02,
#          4.3511194e-01,  5.0326507e-04, -2.7879658e-01, -2.5895801e-01,
#         -2.4279262e-01,  1.1158445e-01,  3.1619403e-01,  3.1753534e-01,
#         -1.3183555e-01,  4.0391237e-01,  4.8740411e-01,  1.6134145e-03,
#          3.6207208e-01,  4.1499713e-01,  3.5819587e-01,  7.8359872e-02,
#          8.3928429e-02,  5.5315322e-04,  4.8179794e-03, -2.3667416e-02]],
#       dtype=float32), array([ 0.5763189 ,  0.10857808, -0.7472926 , -0.02216879, -0.6916393 ,
#         0.30670565, -0.24206689,  0.13332878,  0.26381198,  0.19511506,
#         0.29662633, -0.13197671,  0.29786748, -0.0083971 ,  0.6694985 ,
#         0.21015643, -0.8283723 , -0.03457905,  0.7559842 ,  0.19104497,
#         0.09049685, -0.04621683, -0.32076493, -0.3321562 , -0.26362398,
#         0.2908418 ,  0.1951135 ,  0.24258041, -0.72133464, -0.4394371 ,
#        -0.43302915, -0.02720774, -0.3920092 , -0.47290337,  0.30674335,
#         0.77210724,  0.841289  , -0.00897525, -0.01563014, -0.24336718],
#       dtype=float32)]

# %% [markdown]
# It is possible to get all weights at once:

# %%
all_weights = model.get_weights()

# %%
print("total weights arrays available:", len(all_weights))
for i, weights in enumerate(all_weights):
    print(i, weights.shape)
# Out:
# total weights arrays available: 10
# 0 (1, 40)
# 1 (40,)
# 2 (40, 30)
# 3 (30,)
# 4 (30, 20)
# 5 (20,)
# 6 (20, 10)
# 7 (10,)
# 8 (10, 1)
# 9 (1,)

# %% [markdown]
# It is possible to manually modify weights and set them back into layer [https://keras.io/api/layers/base_layer/#set_weights-method](https://keras.io/api/layers/base_layer/#set_weights-method):

# %%
one_layer = model.get_layer(name="dense_1")
one_layer_weights = one_layer.get_weights()

# %% [markdown]
# Modify just one value

# %%
#the first layer "dense_1" weigths (weights have index 0, biases index 1) have shape (1, 40)
#we change second value at index 1
one_layer_weights[0][0][1] = -10 # [weights index][0 - as there just one input][1 - because we change second weight]
one_layer.set_weights(one_layer_weights)

# %% [markdown]
# and observe the result

# %%
predicted_data = model.predict(input_data)

# %%
plt.figure()
plt.grid()
plt.title("Prediction vs original")
plt.xlabel("x")
plt.ylabel("y")
#plt.plot(input_data[0:100], output_data[0:100]);
#plt.plot(input_data, predicted_data);
plt.plot(input_data, output_data, input_data, predicted_data);
print(predicted_data.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ## Custom activation functions

# %% [markdown]
# We can try and make a model with a custom activation function.

# %%
# you can try this activation too
def sin_activation(x):
    return keras.backend.sin(x)

# we will use this periodic function
def cos_activation(x):
    return keras.backend.cos(x)

def experimental_model2():
    # single input will be two floating point numbers supplied at the same time (vector of two number)
    model_input = keras.layers.Input(shape=(1,), dtype="float32", name="input")

    # activation could be defined as separate layer or as part of the current layer (if supported)
    x = keras.layers.Dense(40, use_bias=True, activation=cos_activation, name="dense_1")(model_input)
    x = keras.layers.Dense(30, use_bias=True, activation=cos_activation, name="dense_2")(x)
    x = keras.layers.Dense(20, use_bias=True, activation=cos_activation, name="dense_3")(x)
    x = keras.layers.Dense(10, use_bias=True, activation=cos_activation, name="dense_4")(x)
    model_output = keras.layers.Dense(1, use_bias=True, name="dense_output")(x)
    # now model inputs and outputs should be provided in a lists
    model = keras.Model(inputs=[model_input], outputs=[model_output])
    
    return model

# you can try to experiment with smaller models and see if it is possible to get low loss on train and validation data
# try adding more layers and train again
def experimental_model3():
    # single input will be two floating point numbers supplied at the same time (vector of two number)
    model_input = keras.layers.Input(shape=(1,), dtype="float32", name="input")
    # activation could be defined as separate layer or as part of the current layer (if supported)
    model_output = keras.layers.Dense(1, use_bias=True, activation=cos_activation, name="dense_1")(model_input)
    # now model inputs and outputs should be provided in a lists
    model = keras.Model(inputs=[model_input], outputs=[model_output])
    
    return model

# %% [markdown]
# Lets build a model and train it

# %%
model2 = experimental_model2()

# uncomment this line if you wish to test experimental_model3()
#model2 = experimental_model3()

opt = keras.optimizers.Adam()
#opt = keras.optimizers.RMSprop()
loss = keras.losses.MeanSquaredError()
metric_mae = keras.metrics.MeanAbsoluteError()
model2.compile(optimizer=opt,
              loss=loss,
              metrics=[metric_mae],
              run_eagerly=False,)

batch_size = 16
epochs = 50

#model.fit(input_data, output_data, batch_size=batch_size, epochs=epochs, validation_split=0.1)
model2.fit(shuffled_input_data,
           shuffled_output_data,
           batch_size=batch_size,
           epochs=epochs,
           validation_split=0.1);
# Out:
# Epoch 1/50
# 57/57 [==============================] - 1s 5ms/step - loss: 1.5457 - mean_absolute_error: 0.9586 - val_loss: 0.9388 - val_mean_absolute_error: 0.7789
# Epoch 2/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.9528 - mean_absolute_error: 0.7649 - val_loss: 0.9198 - val_mean_absolute_error: 0.7714
# Epoch 3/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.9406 - mean_absolute_error: 0.7619 - val_loss: 0.9034 - val_mean_absolute_error: 0.7627
# Epoch 4/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.9105 - mean_absolute_error: 0.7529 - val_loss: 0.8944 - val_mean_absolute_error: 0.7755
# Epoch 5/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.8266 - mean_absolute_error: 0.7325 - val_loss: 0.6947 - val_mean_absolute_error: 0.7076
# Epoch 6/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.6826 - mean_absolute_error: 0.6757 - val_loss: 0.4926 - val_mean_absolute_error: 0.6050
# Epoch 7/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4871 - mean_absolute_error: 0.5823 - val_loss: 0.3762 - val_mean_absolute_error: 0.5170
# Epoch 8/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.4092 - mean_absolute_error: 0.5202 - val_loss: 0.2982 - val_mean_absolute_error: 0.4492
# Epoch 9/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3188 - mean_absolute_error: 0.4545 - val_loss: 0.2135 - val_mean_absolute_error: 0.3710
# Epoch 10/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2610 - mean_absolute_error: 0.3913 - val_loss: 0.2849 - val_mean_absolute_error: 0.3958
# Epoch 11/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.2147 - mean_absolute_error: 0.3566 - val_loss: 0.1303 - val_mean_absolute_error: 0.2856
# Epoch 12/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1439 - mean_absolute_error: 0.3043 - val_loss: 0.1344 - val_mean_absolute_error: 0.2701
# Epoch 13/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1208 - mean_absolute_error: 0.2816 - val_loss: 0.0994 - val_mean_absolute_error: 0.2472
# Epoch 14/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1149 - mean_absolute_error: 0.2702 - val_loss: 0.0755 - val_mean_absolute_error: 0.2195
# Epoch 15/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0946 - mean_absolute_error: 0.2436 - val_loss: 0.0622 - val_mean_absolute_error: 0.2024
# Epoch 16/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0615 - mean_absolute_error: 0.2040 - val_loss: 0.0498 - val_mean_absolute_error: 0.1758
# Epoch 17/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0508 - mean_absolute_error: 0.1808 - val_loss: 0.0405 - val_mean_absolute_error: 0.1570
# Epoch 18/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0399 - mean_absolute_error: 0.1601 - val_loss: 0.0267 - val_mean_absolute_error: 0.1294
# Epoch 19/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0294 - mean_absolute_error: 0.1379 - val_loss: 0.0282 - val_mean_absolute_error: 0.1257
# Epoch 20/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0251 - mean_absolute_error: 0.1213 - val_loss: 0.0179 - val_mean_absolute_error: 0.1061
# Epoch 21/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0187 - mean_absolute_error: 0.1060 - val_loss: 0.0364 - val_mean_absolute_error: 0.1429
# Epoch 22/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0162 - mean_absolute_error: 0.0971 - val_loss: 0.0325 - val_mean_absolute_error: 0.1219
# Epoch 23/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0116 - mean_absolute_error: 0.0831 - val_loss: 0.0095 - val_mean_absolute_error: 0.0746
# Epoch 24/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0096 - mean_absolute_error: 0.0761 - val_loss: 0.0087 - val_mean_absolute_error: 0.0768
# Epoch 25/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0644 - val_loss: 0.0072 - val_mean_absolute_error: 0.0637
# Epoch 26/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0577 - val_loss: 0.0058 - val_mean_absolute_error: 0.0609
# Epoch 27/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0557 - val_loss: 0.0049 - val_mean_absolute_error: 0.0535
# Epoch 28/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_error: 0.0494 - val_loss: 0.0039 - val_mean_absolute_error: 0.0488
# Epoch 29/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0451 - val_loss: 0.0035 - val_mean_absolute_error: 0.0454
# Epoch 30/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0029 - mean_absolute_error: 0.0421 - val_loss: 0.0045 - val_mean_absolute_error: 0.0513
# Epoch 31/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0458 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388
# Epoch 32/50
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0424 - val_loss: 0.0037 - val_mean_absolute_error: 0.0471
# Epoch 33/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0446 - val_loss: 0.0025 - val_mean_absolute_error: 0.0417
# Epoch 34/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0417 - val_loss: 0.0023 - val_mean_absolute_error: 0.0386
# Epoch 35/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0369 - val_loss: 0.0030 - val_mean_absolute_error: 0.0446
# Epoch 36/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0517 - val_loss: 0.0055 - val_mean_absolute_error: 0.0539
# Epoch 37/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_error: 0.0430 - val_loss: 0.0030 - val_mean_absolute_error: 0.0434
# Epoch 38/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0424 - val_loss: 0.0030 - val_mean_absolute_error: 0.0455
# Epoch 39/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0378 - val_loss: 0.0026 - val_mean_absolute_error: 0.0423
# Epoch 40/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0361 - val_loss: 0.0022 - val_mean_absolute_error: 0.0352
# Epoch 41/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0329 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 42/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0347 - val_loss: 0.0063 - val_mean_absolute_error: 0.0612
# Epoch 43/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0031 - mean_absolute_error: 0.0404 - val_loss: 0.0025 - val_mean_absolute_error: 0.0376
# Epoch 44/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0402 - val_loss: 0.0036 - val_mean_absolute_error: 0.0459
# Epoch 45/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0025 - mean_absolute_error: 0.0366 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 46/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0330 - val_loss: 0.0012 - val_mean_absolute_error: 0.0281
# Epoch 47/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0322 - val_loss: 0.0019 - val_mean_absolute_error: 0.0336
# Epoch 48/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0015 - val_mean_absolute_error: 0.0289
# Epoch 49/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0352 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
# Epoch 50/50
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0021 - mean_absolute_error: 0.0340 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324

# %%
predicted_data = model2.predict(input_data)

# %%
plt.figure()
plt.grid()
plt.title("Prediction vs original")
plt.xlabel("x")
plt.ylabel("y")
#plt.plot(input_data[0:100], output_data[0:100]);
#plt.plot(input_data, predicted_data);
plt.plot(input_data, output_data, input_data, predicted_data);
print(predicted_data.shape)
# Out:
# (1000, 1)

# %% [markdown]
# Looks good on a limited set of data. But how will it behave if we extend the range of input values?

# %%
input_data_long = np.linspace(-20, 20, num=1000)
#output_data_long = np.sin(input_data_long)
output_data_long = np.sin(2*input_data_long) + np.sin(input_data_long)

# %%
predicted_data_long = model2.predict(input_data_long)

# %%
plt.figure()
plt.grid()
plt.title("Prediction vs original (long version)")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(input_data_long, output_data_long, input_data_long, predicted_data_long);
print(predicted_data_long.shape)
# Out:
# (1000, 1)

# %% [markdown]
# We saw the results, model overfits: result is good on limited range of train data (low bias) and bad on a wider set of test data (high variance). Here one problem is that test data is from a different range. Solution could be to provide more data or simplify the model. Because even with periodic activation functions we couldn't get model to perform well, the problem may be that our train data was not representing periodicy well. So now we make a big dataset with a wider range of values to better represent the periodicy of the data.

# %%
input_data_big = np.linspace(-1000, 1000, num=100000)
#output_data_big = np.sin(input_data_big)
output_data_big = np.sin(2*input_data_big) + np.sin(input_data_big)

# %%
shuffled_input_data_big, shuffled_output_data_big = shuffled_copies(input_data_big, output_data_big)

# %%
# if you comment line below, you will use previous model pre-trained on small set
# that could help if current model is not training on a large set
#model2 = experimental_model2() 

opt = keras.optimizers.Adam()
#opt = keras.optimizers.RMSprop()
loss = keras.losses.MeanSquaredError()
metric_mae = keras.metrics.MeanAbsoluteError()
model2.compile(optimizer=opt,
              loss=loss,
              metrics=[metric_mae],
              run_eagerly=False,)

# %%
os.makedirs("weights", exist_ok=True) #make folder for storing model weights

#let's save promising models during training
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(filepath="weights/weights.{epoch:02d}-{val_loss:.2f}.hdf5",
                                                            save_weights_only=True, #saving weights, as we have custom activation
                                                            monitor='val_loss', #we will watch validation loss
                                                            mode='min', #we want to save minimum validation loss only
                                                            save_best_only=True)


batch_size = 16
epochs = 50

#we will store training history in train_history
train_history = model2.fit(shuffled_input_data_big,
                           shuffled_output_data_big,
                           batch_size=batch_size,
                           epochs=epochs,
                           callbacks=[model_checkpoint_callback],
                           validation_split=0.1);
# Out:
# Epoch 1/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 1.0065 - mean_absolute_error: 0.7996 - val_loss: 0.9795 - val_mean_absolute_error: 0.7863
# Epoch 2/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.9978 - mean_absolute_error: 0.7953 - val_loss: 0.9770 - val_mean_absolute_error: 0.7851
# Epoch 3/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.9903 - mean_absolute_error: 0.7928 - val_loss: 0.9761 - val_mean_absolute_error: 0.7835
# Epoch 4/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.9934 - mean_absolute_error: 0.7923 - val_loss: 0.9643 - val_mean_absolute_error: 0.7793
# Epoch 5/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.9144 - mean_absolute_error: 0.7689 - val_loss: 0.7322 - val_mean_absolute_error: 0.7059
# Epoch 6/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.7889 - mean_absolute_error: 0.7240 - val_loss: 0.7032 - val_mean_absolute_error: 0.6783
# Epoch 7/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.6644 - mean_absolute_error: 0.6622 - val_loss: 0.6426 - val_mean_absolute_error: 0.6566
# Epoch 8/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.7220 - mean_absolute_error: 0.6980 - val_loss: 0.7067 - val_mean_absolute_error: 0.6875
# Epoch 9/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.7608 - mean_absolute_error: 0.7141 - val_loss: 0.6830 - val_mean_absolute_error: 0.6922
# Epoch 10/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.7170 - mean_absolute_error: 0.6972 - val_loss: 0.6241 - val_mean_absolute_error: 0.6616
# Epoch 11/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.7809 - mean_absolute_error: 0.7272 - val_loss: 0.8301 - val_mean_absolute_error: 0.7432
# Epoch 12/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.7846 - mean_absolute_error: 0.7329 - val_loss: 0.6689 - val_mean_absolute_error: 0.6862
# Epoch 13/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.7353 - mean_absolute_error: 0.6981 - val_loss: 0.9012 - val_mean_absolute_error: 0.7635
# Epoch 14/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.8120 - mean_absolute_error: 0.7338 - val_loss: 0.6971 - val_mean_absolute_error: 0.6980
# Epoch 15/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.6259 - mean_absolute_error: 0.6463 - val_loss: 1.2714 - val_mean_absolute_error: 0.9122
# Epoch 16/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.1709 - mean_absolute_error: 0.2449 - val_loss: 0.0035 - val_mean_absolute_error: 0.0455
# Epoch 17/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.3530 - mean_absolute_error: 0.3920 - val_loss: 0.1847 - val_mean_absolute_error: 0.3371
# Epoch 18/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.1655 - mean_absolute_error: 0.3023 - val_loss: 0.0990 - val_mean_absolute_error: 0.2328
# Epoch 19/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0440 - mean_absolute_error: 0.1266 - val_loss: 0.0125 - val_mean_absolute_error: 0.0818
# Epoch 20/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0222 - mean_absolute_error: 0.0863 - val_loss: 0.0034 - val_mean_absolute_error: 0.0439
# Epoch 21/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0811 - mean_absolute_error: 0.1718 - val_loss: 0.0020 - val_mean_absolute_error: 0.0339
# Epoch 22/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.1726 - mean_absolute_error: 0.2388 - val_loss: 0.2084 - val_mean_absolute_error: 0.3638
# Epoch 23/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0514 - mean_absolute_error: 0.1382 - val_loss: 0.0016 - val_mean_absolute_error: 0.0322
# Epoch 24/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0741 - mean_absolute_error: 0.1597 - val_loss: 0.0049 - val_mean_absolute_error: 0.0551
# Epoch 25/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0155 - mean_absolute_error: 0.0664 - val_loss: 0.0029 - val_mean_absolute_error: 0.0407
# Epoch 26/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.0533 - val_loss: 4.0859e-04 - val_mean_absolute_error: 0.0159
# Epoch 27/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0131 - mean_absolute_error: 0.0544 - val_loss: 0.0054 - val_mean_absolute_error: 0.0563
# Epoch 28/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0147 - mean_absolute_error: 0.0552 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 29/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0206 - mean_absolute_error: 0.0616 - val_loss: 0.0024 - val_mean_absolute_error: 0.0350
# Epoch 30/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0186 - mean_absolute_error: 0.0630 - val_loss: 0.0043 - val_mean_absolute_error: 0.0518
# Epoch 31/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0131 - mean_absolute_error: 0.0557 - val_loss: 4.9006e-04 - val_mean_absolute_error: 0.0177
# Epoch 32/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.3913 - mean_absolute_error: 0.3583 - val_loss: 0.7638 - val_mean_absolute_error: 0.7118
# Epoch 33/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.1285 - mean_absolute_error: 0.2096 - val_loss: 0.3408 - val_mean_absolute_error: 0.4601
# Epoch 34/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.1512 - mean_absolute_error: 0.2879 - val_loss: 0.0910 - val_mean_absolute_error: 0.2099
# Epoch 35/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0918 - mean_absolute_error: 0.2013 - val_loss: 0.0036 - val_mean_absolute_error: 0.0463
# Epoch 36/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0257 - mean_absolute_error: 0.0894 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 37/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.0583 - val_loss: 0.0045 - val_mean_absolute_error: 0.0511
# Epoch 38/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0433 - mean_absolute_error: 0.1061 - val_loss: 0.0043 - val_mean_absolute_error: 0.0495
# Epoch 39/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0126 - mean_absolute_error: 0.0543 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
# Epoch 40/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0132 - mean_absolute_error: 0.0549 - val_loss: 4.0234e-04 - val_mean_absolute_error: 0.0154
# Epoch 41/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0120 - mean_absolute_error: 0.0503 - val_loss: 0.0653 - val_mean_absolute_error: 0.1778
# Epoch 42/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.3768 - mean_absolute_error: 0.4385 - val_loss: 0.1091 - val_mean_absolute_error: 0.2489
# Epoch 43/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.1245 - mean_absolute_error: 0.2540 - val_loss: 0.0531 - val_mean_absolute_error: 0.1582
# Epoch 44/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.1100 - mean_absolute_error: 0.2264 - val_loss: 0.0720 - val_mean_absolute_error: 0.1948
# Epoch 45/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0929 - mean_absolute_error: 0.1964 - val_loss: 0.0438 - val_mean_absolute_error: 0.1629
# Epoch 46/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0152 - mean_absolute_error: 0.0691 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 47/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0194 - mean_absolute_error: 0.0637 - val_loss: 6.8027e-04 - val_mean_absolute_error: 0.0201
# Epoch 48/50
# 5625/5625 [==============================] - 11s 2ms/step - loss: 0.0993 - mean_absolute_error: 0.1612 - val_loss: 0.2289 - val_mean_absolute_error: 0.3903
# Epoch 49/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0600 - mean_absolute_error: 0.1370 - val_loss: 7.9109e-04 - val_mean_absolute_error: 0.0218
# Epoch 50/50
# 5625/5625 [==============================] - 10s 2ms/step - loss: 0.0138 - mean_absolute_error: 0.0549 - val_loss: 3.5535e-04 - val_mean_absolute_error: 0.0149

# %% [markdown]
# `fit` method returns train history dictionary, which could be used to check model performance during training. Let's see what keys are available:

# %%
print(train_history.history.keys())
print("Items in 'loss' key:", len(train_history.history['loss']))
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])
# Items in 'loss' key: 50

# %% [markdown]
# We would like to compare `loss` (on train set) and `val_loss` (validation loss on dev set).

# %%
epochs = list(range(len(train_history.history['loss'])))

plt.figure()
plt.grid()
plt.title("Training")
plt.xlabel("epoch")
plt.ylabel("loss")
#plt.plot(input_data[0:100], output_data[0:100]);
#plt.plot(input_data, predicted_data);
plt.plot(epochs, train_history.history['loss'], epochs, train_history.history['val_loss']);

# %% [markdown]
# TODO: Add loading best model and testing it.

# %%
input_data_long = np.linspace(-5000, -4990, num=1000)
#output_data_long = np.sin(input_data_long)
output_data_long = np.sin(2*input_data_long) + np.sin(input_data_long)

# %%
predicted_data_long = model2.predict(input_data_long)

# %%
plt.figure()
plt.grid()
plt.title("Prediction vs original (long version)")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(input_data_long, output_data_long, input_data_long, predicted_data_long);
print(predicted_data_long.shape)
# Out:
# (1000, 1)

# %% [markdown]
# As we can see our test data is way outside of the train range and model is still behaving well. So conclusion could be that model learned periodicy of data well.
